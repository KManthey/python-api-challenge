# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
#query_url = base_url q={city name}&appid={API key}”
query_url = base_url + "&appid=" + weather_api_key + "&q=" + city + "&units=" + units
#have tried both api_keys, api_key, weather_api_key
#removed from query for testing  + "&units=" + units
lats = []
lngs = []
temps = []
hums = []
winds = []
clouds = []
countries = []
dates = []
city_count = []
counter = 0

for city in cities[:10]:
    query_url = base_url + "&appid=" + weather_api_key + "&q=" + city + "&units=" + units
    print(city)
    #response = requests.get(query_url)
    #respons_json = response.json()
    response = requests.get(query_url)
    
    #city? 1 do I need to add a list for the city since there is a list already --there is no city in the response data?
    try:
        response = response.json()
    # 2 since I have city in my query_url does it need to be here too?
        lngs.append(response['coord']['lon'])
        lats.append(response['coord']['lat'])
        temps.append(response['main']['temp_max'])
        hums.append(response['main']['humidity'])
        winds.append(response['wind']['speed'])
        clouds.append(response['clouds']['all'])
        dates.append(response['dt'])
        countries.append(response['sys']['country'])
        city_count.append(city)
        counter = counter +1
        print(f"{counter} || {city}")
        time.sleep(1)
    except:
        print("city not found")
# Out:
# tommot
# 1 || tommot
# mys shmidta
# city not found
# tiksi
# 2 || tiksi
# tarata
# 3 || tarata
# fort nelson
# 4 || fort nelson
# longyearbyen
# 5 || longyearbyen
# villa carlos paz
# 6 || villa carlos paz
# tazovskiy
# 7 || tazovskiy
# bredasdorp
# 8 || bredasdorp
# henderson
# 9 || henderson
# coahuayana
# 10 || coahuayana
# katsuura
# 11 || katsuura
# san juan
# 12 || san juan
# arraial do cabo
# 13 || arraial do cabo
# ribeira grande
# 14 || ribeira grande
# port lincoln
# 15 || port lincoln
# saint george
# 16 || saint george
# milkovo
# 17 || milkovo
# nikolskoye
# 18 || nikolskoye
# faya
# 19 || faya
# bozoum
# 20 || bozoum
# provideniya
# 21 || provideniya
# ponta do sol
# 22 || ponta do sol
# ust-nera
# 23 || ust-nera
# hanyang
# 24 || hanyang
# luganville
# 25 || luganville
# hobart
# 26 || hobart
# rikitea
# 27 || rikitea
# mar del plata
# 28 || mar del plata
# bethel
# 29 || bethel
# chuy
# 30 || chuy
# araouane
# 31 || araouane
# cabo san lucas
# 32 || cabo san lucas
# puri
# 33 || puri
# kapaa
# 34 || kapaa
# port elizabeth
# 35 || port elizabeth
# charters towers
# 36 || charters towers
# nortelandia
# 37 || nortelandia
# ushuaia
# 38 || ushuaia
# hilo
# 39 || hilo
# butaritari
# 40 || butaritari
# carrick-on-suir
# 41 || carrick-on-suir
# castro
# 42 || castro
# barra dos coqueiros
# 43 || barra dos coqueiros
# taolanaro
# city not found
# cidreira
# 44 || cidreira
# tsihombe
# city not found
# punta arenas
# 45 || punta arenas
# georgetown
# 46 || georgetown
# chokurdakh
# 47 || chokurdakh

# %%
print(len(lngs))
print(len(lats))
print(len(temps))
print(len(hums))
print(len(winds))
print(len(clouds))
print(len(dates))
print(len(countries))
print(len(city_count))
# Out:
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 47

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
     "City": city_count,
     "Lat": lats,
     "Lng": lngs,
     "Max Temp": temps,
     "Humidity": hums,
     "Cloudiness": clouds,
     "Wind Speed": winds,
     "Country": countries,
     "Date": dates
}

city_data = pd.DataFrame(data = weather_dict)
city_data.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        tommot  58.96  126.29     22.37        94         100       10.45
# 1         tiksi  71.69  128.87     11.25        95          15        4.74
# 2        tarata -17.62  -66.02     78.80        26          20        4.70
# 3   fort nelson  58.81 -122.70     30.20        86          90        3.36
# 4  longyearbyen  78.22   15.64     35.60        69          75       11.41
#
#   Country        Date
# 0      RU  1602619928
# 1      RU  1602620077
# 2      BO  1602620078
# 3      CA  1602620079
# 4      SJ  1602619840

# %%
#Save as CSV so do not have to keep running
city_data.to_csv("city_data.csv")

# %%
#view current path for the csv
#!pwd

# %%
#something like this
#I think they want us to use .describe
#city_stats = city_data.groupby('City')
#or city_stats = city_data.groupby('cities_postextract')
city_data.describe()

#https://www.geeksforgeeks.org/python-pandas-dataframe-describe-method/
# Out:
#              Lat         Lng   Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  47.000000   47.000000  47.000000   47.000000   47.000000   47.000000
# mean   11.520213    2.826170  62.248723   71.000000   45.468085    8.813404
# std    39.253884  102.849808  22.145285   25.073804   38.559864    7.241328
# min   -54.800000 -173.300000  11.250000   12.000000    0.000000    1.010000
# 25%   -23.955000  -68.420000  43.995000   68.000000    6.000000    3.970000
# 50%    18.730000  -17.100000  64.400000   76.000000   40.000000    7.960000
# 75%    39.945000  102.925000  79.405000   88.500000   76.500000   11.295000
# max    78.220000  172.790000  99.860000  100.000000  100.000000   42.500000
#
#                Date
# count  4.700000e+01
# mean   1.602620e+09
# std    9.785389e+01
# min    1.602620e+09
# 25%    1.602620e+09
# 50%    1.602620e+09
# 75%    1.602620e+09
# max    1.602620e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#something like this

max_humidity = city_data[city_data["Humidity"] > 100].index
max_humidity
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data.drop(max_humidity, inplace=False)
clean_city_data
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                tommot  58.96  126.29     22.37        94         100
# 1                 tiksi  71.69  128.87     11.25        95          15
# 2                tarata -17.62  -66.02     78.80        26          20
# 3           fort nelson  58.81 -122.70     30.20        86          90
# 4          longyearbyen  78.22   15.64     35.60        69          75
# 5      villa carlos paz -31.42  -64.50     86.00        17         100
# 6             tazovskiy  67.47   78.70     37.69        95         100
# 7            bredasdorp -34.53   20.04     51.80        76           0
# 8             henderson  36.04 -114.98     89.01        12           1
# 9            coahuayana  18.73 -103.68     84.20        74          40
# 10             katsuura  35.13  140.30     68.00        72          75
# 11             san juan -31.54  -68.54     90.07        12          16
# 12      arraial do cabo -22.97  -42.03     78.80        69           0
# 13       ribeira grande  38.52  -28.70     69.80        77          75
# 14         port lincoln -34.73  135.87     60.87        81          20
# 15         saint george  37.10 -113.58     80.01        15           1
# 16              milkovo  54.72  158.62     35.56        85         100
# 17           nikolskoye  59.70   30.79     46.99        93          75
# 18                 faya  18.39   42.45     62.60        82           0
# 19               bozoum   6.32   16.38     70.03        90          63
# 20          provideniya  64.38 -173.30     28.40        68          75
# 21         ponta do sol  32.67  -17.10     69.80        73          20
# 22             ust-nera  64.57  143.20     33.21        91         100
# 23              hanyang  32.14  105.51     60.01        79         100
# 24           luganville -15.53  167.17     77.00       100          75
# 25               hobart -42.88  147.33     41.00        93          20
# 26              rikitea -23.12 -134.97     72.93        73           0
# 27        mar del plata -38.00  -57.56     64.40        68           0
# 28               bethel  41.37  -73.41     57.20        87          90
# 29                 chuy -33.70  -53.46     61.92        77          23
# 30             araouane  18.90   -3.53     96.76        17           0
# 31       cabo san lucas  22.89 -109.91     87.01        62          40
# 32                 puri  19.80   85.85     78.80       100          75
# 33                kapaa  22.08 -159.32     82.40        74          40
# 34       port elizabeth -33.92   25.57     54.00        76           0
# 35      charters towers -20.10  146.27     62.24        91           0
# 36          nortelandia -14.45  -56.80     99.86        25          65
# 37              ushuaia -54.80  -68.30     41.00        86          40
# 38                 hilo  19.73 -155.09     80.60        61           1
# 39           butaritari   3.07  172.79     81.46        74          78
# 40      carrick-on-suir  52.35   -7.41     52.00        84          11
# 41               castro -24.79  -50.01     73.94        55          95
# 42  barra dos coqueiros -10.91  -37.04     82.40        58          20
# 43             cidreira -30.18  -50.21     63.43        76           0
# 44         punta arenas -53.15  -70.92     41.00        80          90
# 45           georgetown   5.41  100.34     77.00        94          20
# 46           chokurdakh  70.63  147.92     16.27        95          93
#
#     Wind Speed Country        Date
# 0        10.45      RU  1602619928
# 1         4.74      RU  1602620077
# 2         4.70      BO  1602620078
# 3         3.36      CA  1602620079
# 4        11.41      SJ  1602619840
# 5        17.22      AR  1602620081
# 6        17.49      RU  1602620082
# 7         2.71      ZA  1602620084
# 8         1.57      US  1602619920
# 9         5.23      MX  1602620086
# 10        9.17      JP  1602620045
# 11        6.04      AR  1602620088
# 12       21.92      BR  1602620090
# 13       13.87      PT  1602619895
# 14       10.56      AU  1602620092
# 15        3.36      US  1602620093
# 16        3.44      RU  1602620094
# 17        1.52      RU  1602619887
# 18        2.44      SA  1602620096
# 19        1.90      CF  1602620098
# 20       11.18      RU  1602620099
# 21       14.99      PT  1602620100
# 22        5.59      RU  1602620102
# 23        8.55      CN  1602620103
# 24        2.24      VU  1602620105
# 25        8.05      AU  1602619907
# 26       13.91      PF  1602620108
# 27       14.99      AR  1602620087
# 28        9.17      US  1602619943
# 29        7.18      UY  1602620112
# 30        8.68      ML  1602619872
# 31       10.29      MX  1602619833
# 32        3.36      IN  1602620115
# 33       16.11      US  1602619872
# 34        1.01      ZA  1602620118
# 35        8.08      AU  1602620119
# 36        5.30      BR  1602619934
# 37        4.70      AR  1602620121
# 38        7.96      US  1602619887
# 39       19.39      KI  1602619876
# 40        4.00      IE  1602620125
# 41        4.23      BR  1602619972
# 42       11.41      BR  1602620127
# 43        9.82      BR  1602620128
# 44       42.50      CL  1602620049
# 45        4.50      MY  1602619898
# 46        3.94      RU  1602620132

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Scatter plot of latitude vs max tempurature
plt.scatter(clean_city_data["Lat"], clean_city_data["Max Temp"], marker="o")

# Graph properties
plt.title("City Latitude vs Max Temperature (10/13/2020)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save figure
plt.savefig("Lat_vs_Temp.png")

# Display
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Scatter plot of latitude vs humidity
plt.scatter(clean_city_data["Lat"], clean_city_data["Humidity"], marker="o")

# Graph properties
plt.title("City Latitude vs Humidity (10/13/2020)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save figure
plt.savefig("Lat_vs_Humidity.png")

# Display
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Scatter plot of latitude vs cloudiness
plt.scatter(clean_city_data["Lat"], clean_city_data["Cloudiness"], marker="o")

# Graph properties
plt.title("City Latitude vs Cloudiness (10/13/2020)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save figure
plt.savefig("Lat_vs_Clouds.png")

# Display
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Scatter plot of latitude vs cloudiness
plt.scatter(clean_city_data["Lat"], clean_city_data["Wind Speed"], marker="o")

# Graph properties
plt.title("City Latitude vs Wind Speed (10/13/2020)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save figure
plt.savefig("Lat_vs_Wind.png")

# Display
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Separate out northern hemisphere
northern_df = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]

# Define X and Y values
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6129dddb3102> in <module>
#       1 #create NH dataframe
# ----> 2 northern_df = clean_city_data.loc[clean_city_data["Lat"] >= 0]
#       3 # Create Plot
#       4 plt.scatter(x_values,y_values)
#       5 plt.plot(x_values,regress_values,"r-")
#
# NameError: name 'clean_city_data' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Separate out southern hemisphere
southern_df = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]

# Define X and Y values
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# The r-value is: 0.1773341513873757

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Separate out northern hemisphere
northern_df = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]

# Define X and Y values
x_values = northern_df['Lat']
y_values = northern_df['Humidity']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# The r-value is: 0.1773341513873757

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Separate out southern hemisphere
southern_df = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]

# Define X and Y values
x_values = southern_df['Lat']
y_values = southern_df['Humidity']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# The r-value is: 0.1773341513873757

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Separate out northern hemisphere
northern_df = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]

# Define X and Y values
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#below these are not redone

#create NH dataframe
southern_df = clean_city_data.loc[clean_city_data["Lat"] <=0]
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
#plt.ylim(0, 80)
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save figure to file and print
#plt.savefig("../my_images/linear_regression.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#create NH dataframe
southern_df = clean_city_data.loc[clean_city_data["Lat"] >=0]
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
#plt.ylim(0, 80)
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save figure to file and print
#plt.savefig("../my_images/linear_regression.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#create NH dataframe
southern_df = clean_city_data.loc[clean_city_data["Lat"] <=0]
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
#plt.ylim(0, 80)
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save figure to file and print
#plt.savefig("../my_images/linear_regression.png")
plt.show()
# Out:
# The r-value is: 0.1773341513873757
