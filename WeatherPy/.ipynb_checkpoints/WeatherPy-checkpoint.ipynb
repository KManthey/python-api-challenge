# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Call API
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = base_url + "&appid=" + weather_api_key + "&q=" + city + "&units=" + units

# Create lists to hold API data
lats = []
lngs = []
temps = []
hums = []
winds = []
clouds = []
countries = []
dates = []
city_count = []

# Create loop for request and response
counter = 0

for city in cities[:500]:
    query_url = base_url + "&appid=" + weather_api_key + "&q=" + city + "&units=" + units
    print(city)
    response = requests.get(query_url)
    
    # Add responses to lists and continue if city is not found
    # Print counter and city - add sleep time between calls
    try:
        response = response.json()
        lngs.append(response['coord']['lon'])
        lats.append(response['coord']['lat'])
        temps.append(response['main']['temp_max'])
        hums.append(response['main']['humidity'])
        winds.append(response['wind']['speed'])
        clouds.append(response['clouds']['all'])
        dates.append(response['dt'])
        countries.append(response['sys']['country'])
        city_count.append(city)
        counter = counter +1
        print(f"{counter} || {city}")
        time.sleep(1)
    except:
        print("city not found")
# Out:
# bengkulu
# 1 || bengkulu
# constitucion
# 2 || constitucion
# jalu
# 3 || jalu
# dikson
# 4 || dikson
# taolanaro
# city not found
# victoria
# 5 || victoria
# saint-philippe
# 6 || saint-philippe
# carnarvon
# 7 || carnarvon
# emerald
# 8 || emerald
# mataura
# 9 || mataura
# comodoro rivadavia
# 10 || comodoro rivadavia
# punta arenas
# 11 || punta arenas
# maku
# 12 || maku
# butaritari
# 13 || butaritari
# jamestown
# 14 || jamestown
# vaini
# 15 || vaini
# iquique
# 16 || iquique
# yellowknife
# 17 || yellowknife
# itarema
# 18 || itarema
# iqaluit
# 19 || iqaluit
# atuona
# 20 || atuona
# qaanaaq
# 21 || qaanaaq
# port alfred
# 22 || port alfred
# thompson
# 23 || thompson
# rikitea
# 24 || rikitea
# boisar
# 25 || boisar
# jinotega
# 26 || jinotega
# georgetown
# 27 || georgetown
# opole lubelskie
# 28 || opole lubelskie
# verkhnevilyuysk
# 29 || verkhnevilyuysk
# east london
# 30 || east london
# kodiak
# 31 || kodiak
# hirara
# 32 || hirara
# berlevag
# 33 || berlevag
# cabo san lucas
# 34 || cabo san lucas
# tura
# 35 || tura
# pangkalanbuun
# 36 || pangkalanbuun
# hiji
# 37 || hiji
# port elizabeth
# 38 || port elizabeth
# kapoeta
# 39 || kapoeta
# ushuaia
# 40 || ushuaia
# nicoya
# 41 || nicoya
# te anau
# 42 || te anau
# puerto ayora
# 43 || puerto ayora
# fortuna
# 44 || fortuna
# kangaatsiaq
# 45 || kangaatsiaq
# alofi
# 46 || alofi
# gigmoto
# 47 || gigmoto
# naze
# 48 || naze
# arcata
# 49 || arcata
# tasiilaq
# 50 || tasiilaq
# ngaoundere
# 51 || ngaoundere
# zyryanka
# 52 || zyryanka
# dudinka
# 53 || dudinka
# bobo dioulasso
# 54 || bobo dioulasso
# leopold
# 55 || leopold
# arlit
# 56 || arlit
# calais
# 57 || calais
# hermanus
# 58 || hermanus
# hobyo
# 59 || hobyo
# castro
# 60 || castro
# los llanos de aridane
# 61 || los llanos de aridane
# albany
# 62 || albany
# litovko
# 63 || litovko
# hoquiam
# 64 || hoquiam
# broken hill
# 65 || broken hill
# bonavista
# 66 || bonavista
# waverley
# 67 || waverley
# antofagasta
# 68 || antofagasta
# severo-kurilsk
# 69 || severo-kurilsk
# san patricio
# 70 || san patricio
# nikolskoye
# 71 || nikolskoye
# cidreira
# 72 || cidreira
# port hardy
# 73 || port hardy
# kajaani
# 74 || kajaani
# maldonado
# 75 || maldonado
# avarua
# 76 || avarua
# katha
# city not found
# aklavik
# 77 || aklavik
# bluff
# 78 || bluff
# dingle
# 79 || dingle
# nome
# 80 || nome
# taoudenni
# 81 || taoudenni
# manokwari
# 82 || manokwari
# mahibadhoo
# 83 || mahibadhoo
# busselton
# 84 || busselton
# honningsvag
# 85 || honningsvag
# grindavik
# 86 || grindavik
# kaitangata
# 87 || kaitangata
# palmer
# 88 || palmer
# new norfolk
# 89 || new norfolk
# vestmannaeyjar
# 90 || vestmannaeyjar
# sitio novo do tocantins
# 91 || sitio novo do tocantins
# kyzyl-suu
# 92 || kyzyl-suu
# mount gambier
# 93 || mount gambier
# hobart
# 94 || hobart
# rungata
# city not found
# grand island
# 95 || grand island
# deputatskiy
# 96 || deputatskiy
# conceicao da barra
# 97 || conceicao da barra
# barrow
# 98 || barrow
# cape town
# 99 || cape town
# bredasdorp
# 100 || bredasdorp
# the valley
# 101 || the valley
# ancud
# 102 || ancud
# baisha
# 103 || baisha
# multan
# 104 || multan
# kapaa
# 105 || kapaa
# ilulissat
# 106 || ilulissat
# faanui
# 107 || faanui
# pangnirtung
# 108 || pangnirtung
# hofn
# 109 || hofn
# norman wells
# 110 || norman wells
# upernavik
# 111 || upernavik
# bilma
# 112 || bilma
# maniitsoq
# 113 || maniitsoq
# touros
# 114 || touros
# cherskiy
# 115 || cherskiy
# portland
# 116 || portland
# leningradskiy
# 117 || leningradskiy
# calama
# 118 || calama
# ulaangom
# 119 || ulaangom
# cockburn town
# 120 || cockburn town
# pisco
# 121 || pisco
# poya
# 122 || poya
# saint george
# 123 || saint george
# boa vista
# 124 || boa vista
# sitka
# 125 || sitka
# san francisco del mar
# 126 || san francisco del mar
# wuwei
# 127 || wuwei
# saleaula
# city not found
# kendari
# 128 || kendari
# bambous virieux
# 129 || bambous virieux
# san ramon
# 130 || san ramon
# boatlaname
# city not found
# rio gallegos
# 131 || rio gallegos
# nelson bay
# 132 || nelson bay
# narsaq
# 133 || narsaq
# lolua
# city not found
# komsomolskiy
# 134 || komsomolskiy
# samatau
# city not found
# rawson
# 135 || rawson
# halmstad
# 136 || halmstad
# bowmore
# 137 || bowmore
# mudanya
# 138 || mudanya
# pathein
# 139 || pathein
# itabirito
# 140 || itabirito
# aswan
# 141 || aswan
# ponta do sol
# 142 || ponta do sol
# bethel
# 143 || bethel
# bajo baudo
# city not found
# tabou
# 144 || tabou
# gamba
# 145 || gamba
# el reno
# 146 || el reno
# tumannyy
# city not found
# katsuura
# 147 || katsuura
# vestmanna
# 148 || vestmanna
# hasaki
# 149 || hasaki
# mouila
# 150 || mouila
# tsihombe
# city not found
# hilo
# 151 || hilo
# sentyabrskiy
# city not found
# rehoboth
# 152 || rehoboth
# moradabad
# 153 || moradabad
# san lorenzo de el escorial
# 154 || san lorenzo de el escorial
# umaria
# 155 || umaria
# bisira
# 156 || bisira
# samana
# 157 || samana
# luganville
# 158 || luganville
# taquarituba
# 159 || taquarituba
# inhambane
# 160 || inhambane
# kaeo
# 161 || kaeo
# kiruna
# 162 || kiruna
# avera
# 163 || avera
# arraial do cabo
# 164 || arraial do cabo
# salalah
# 165 || salalah
# codrington
# 166 || codrington
# yar-sale
# 167 || yar-sale
# wanning
# 168 || wanning
# coquimbo
# 169 || coquimbo
# hamilton
# 170 || hamilton
# saint-pierre
# 171 || saint-pierre
# bagnols-sur-ceze
# 172 || bagnols-sur-ceze
# okha
# 173 || okha
# prince albert
# 174 || prince albert
# atar
# 175 || atar
# dunedin
# 176 || dunedin
# ostrovnoy
# 177 || ostrovnoy
# leh
# 178 || leh
# marawi
# 179 || marawi
# attawapiskat
# city not found
# khandyga
# 180 || khandyga
# kundiawa
# 181 || kundiawa
# bushehr
# 182 || bushehr
# sao filipe
# 183 || sao filipe
# barentsburg
# city not found
# saint-augustin
# 184 || saint-augustin
# bardiyah
# 185 || bardiyah
# axim
# 186 || axim
# namatanai
# 187 || namatanai
# faya
# 188 || faya
# mar del plata
# 189 || mar del plata
# yulara
# 190 || yulara
# samusu
# city not found
# ribeira grande
# 191 || ribeira grande
# koygorodok
# 192 || koygorodok
# la uribe
# city not found
# raudeberg
# 193 || raudeberg
# san rafael del sur
# 194 || san rafael del sur
# sayyan
# 195 || sayyan
# waddan
# 196 || waddan
# amderma
# city not found
# illoqqortoormiut
# city not found
# kandrian
# 197 || kandrian
# henderson
# 198 || henderson
# bolokhovo
# 199 || bolokhovo
# palabuhanratu
# city not found
# ucluelet
# 200 || ucluelet
# soyo
# 201 || soyo
# dauriya
# 202 || dauriya
# norden
# 203 || norden
# pali
# 204 || pali
# north battleford
# 205 || north battleford
# betera
# 206 || betera
# karratha
# 207 || karratha
# chokurdakh
# 208 || chokurdakh
# makinsk
# 209 || makinsk
# thinadhoo
# 210 || thinadhoo
# tuktoyaktuk
# 211 || tuktoyaktuk
# bolungarvik
# city not found
# dalaba
# 212 || dalaba
# sasovo
# 213 || sasovo
# kavieng
# 214 || kavieng
# krasnovishersk
# 215 || krasnovishersk
# khatanga
# 216 || khatanga
# taburi
# city not found
# kyshtovka
# 217 || kyshtovka
# maxixe
# 218 || maxixe
# rio grande
# 219 || rio grande
# asfi
# 220 || asfi
# caravelas
# 221 || caravelas
# alta floresta
# 222 || alta floresta
# vung tau
# 223 || vung tau
# mys shmidta
# city not found
# oistins
# 224 || oistins
# kloulklubed
# 225 || kloulklubed
# broome
# 226 || broome
# tuxpan
# 227 || tuxpan
# bitung
# 228 || bitung
# rochester
# 229 || rochester
# parabel
# 230 || parabel
# tres passos
# 231 || tres passos
# la ronge
# 232 || la ronge
# victor harbor
# 233 || victor harbor
# kruisfontein
# 234 || kruisfontein
# port lincoln
# 235 || port lincoln
# unity
# 236 || unity
# havre-saint-pierre
# 237 || havre-saint-pierre
# port keats
# 238 || port keats
# north bend
# 239 || north bend
# marcona
# city not found
# ahipara
# 240 || ahipara
# airai
# 241 || airai
# chuy
# 242 || chuy
# cayenne
# 243 || cayenne
# belushya guba
# city not found
# lezajsk
# 244 || lezajsk
# berezovyy
# 245 || berezovyy
# lamu
# 246 || lamu
# springdale
# 247 || springdale
# zhigansk
# 248 || zhigansk
# synya
# 249 || synya
# tiksi
# 250 || tiksi
# aykhal
# 251 || aykhal
# vila franca do campo
# 252 || vila franca do campo
# sao miguel do araguaia
# 253 || sao miguel do araguaia
# gizo
# 254 || gizo
# umzimvubu
# city not found
# hithadhoo
# 255 || hithadhoo
# preeceville
# 256 || preeceville
# carutapera
# 257 || carutapera
# mardin
# 258 || mardin
# tiarei
# 259 || tiarei
# rocha
# 260 || rocha
# mazatlan
# 261 || mazatlan
# krasnoarmeysk
# 262 || krasnoarmeysk
# almaznyy
# 263 || almaznyy
# bankja
# city not found
# manadhoo
# 264 || manadhoo
# santa maria
# 265 || santa maria
# ginda
# 266 || ginda
# kaabong
# 267 || kaabong
# malanje
# 268 || malanje
# nikolskoye-na-cheremshane
# city not found
# gat
# 269 || gat
# uni
# 270 || uni
# adrar
# 271 || adrar
# kazalinsk
# city not found
# saskylakh
# 272 || saskylakh
# trelew
# 273 || trelew
# shebalino
# 274 || shebalino
# haines junction
# 275 || haines junction
# qasigiannguit
# 276 || qasigiannguit
# pevek
# 277 || pevek
# iquitos
# 278 || iquitos
# klaksvik
# 279 || klaksvik
# skibbereen
# 280 || skibbereen
# tukrah
# 281 || tukrah
# goundam
# 282 || goundam
# nabire
# 283 || nabire
# souillac
# 284 || souillac
# jining
# 285 || jining
# neiafu
# 286 || neiafu
# kuala kedah
# 287 || kuala kedah
# wangqing
# 288 || wangqing
# klang
# 289 || klang
# buritis
# 290 || buritis
# teguldet
# 291 || teguldet
# henties bay
# 292 || henties bay
# haapu
# city not found
# hopkinton
# 293 || hopkinton
# awjilah
# 294 || awjilah
# mehriz
# 295 || mehriz
# prince rupert
# 296 || prince rupert
# aleksandrovskiy zavod
# 297 || aleksandrovskiy zavod
# longyearbyen
# 298 || longyearbyen
# mahebourg
# 299 || mahebourg
# yeniseysk
# 300 || yeniseysk
# zhanaozen
# 301 || zhanaozen
# pacific grove
# 302 || pacific grove
# norrtalje
# 303 || norrtalje
# osakarovka
# 304 || osakarovka
# saldanha
# 305 || saldanha
# lavrentiya
# 306 || lavrentiya
# durban
# 307 || durban
# radomsko
# 308 || radomsko
# san jose
# 309 || san jose
# todos santos
# 310 || todos santos
# nizhniy kuranakh
# 311 || nizhniy kuranakh
# ulladulla
# 312 || ulladulla
# casablanca
# 313 || casablanca
# saharsa
# 314 || saharsa
# vaitupu
# city not found
# bagdarin
# 315 || bagdarin
# turukhansk
# 316 || turukhansk
# tecoanapa
# 317 || tecoanapa
# chernyshevskiy
# 318 || chernyshevskiy
# marsh harbour
# 319 || marsh harbour
# kalaleh
# 320 || kalaleh
# santa maria del oro
# 321 || santa maria del oro
# vardo
# 322 || vardo
# rabaul
# 323 || rabaul
# acapulco
# 324 || acapulco
# galgani
# city not found
# kifri
# 325 || kifri
# olafsvik
# 326 || olafsvik
# lebu
# 327 || lebu
# campoverde
# 328 || campoverde
# san carlos del zulia
# 329 || san carlos del zulia
# karpogory
# 330 || karpogory
# namibe
# 331 || namibe
# tabat
# 332 || tabat
# ewa beach
# 333 || ewa beach
# chongqing
# 334 || chongqing
# srednekolymsk
# 335 || srednekolymsk
# nurlat
# 336 || nurlat
# christchurch
# 337 || christchurch
# pasni
# 338 || pasni
# atherton
# 339 || atherton
# esperance
# 340 || esperance
# najran
# 341 || najran
# amapa
# 342 || amapa
# skaelskor
# 343 || skaelskor
# sao joao da barra
# 344 || sao joao da barra
# karkaralinsk
# city not found
# nago
# 345 || nago
# jutai
# 346 || jutai
# evensk
# 347 || evensk
# dolores
# 348 || dolores
# merauke
# 349 || merauke
# magistralnyy
# 350 || magistralnyy
# sioux lookout
# 351 || sioux lookout
# jawhar
# 352 || jawhar
# calatayud
# 353 || calatayud
# nouadhibou
# 354 || nouadhibou
# burica
# city not found
# kankon
# 355 || kankon
# asosa
# 356 || asosa
# geraldton
# 357 || geraldton
# tessalit
# 358 || tessalit
# provideniya
# 359 || provideniya
# damietta
# 360 || damietta
# san carlos de bariloche
# 361 || san carlos de bariloche
# tabuk
# 362 || tabuk
# asau
# 363 || asau
# vanimo
# 364 || vanimo
# batagay-alyta
# 365 || batagay-alyta
# petropavlovsk-kamchatskiy
# 366 || petropavlovsk-kamchatskiy
# meulaboh
# 367 || meulaboh
# batemans bay
# 368 || batemans bay
# rovinj
# 369 || rovinj
# coihaique
# 370 || coihaique
# bonthe
# 371 || bonthe
# kurchum
# 372 || kurchum
# sorland
# 373 || sorland
# vidim
# 374 || vidim
# kamenskoye
# city not found
# nanortalik
# 375 || nanortalik
# aksarka
# 376 || aksarka
# blacksburg
# 377 || blacksburg
# pestretsy
# 378 || pestretsy
# miri
# 379 || miri
# scottsburgh
# city not found
# dezful
# 380 || dezful
# alice springs
# 381 || alice springs
# tabiauea
# city not found
# kieta
# 382 || kieta
# kahului
# 383 || kahului
# coos bay
# 384 || coos bay
# kropotkin
# 385 || kropotkin
# kavaratti
# 386 || kavaratti
# autun
# 387 || autun
# vila velha
# 388 || vila velha
# lompoc
# 389 || lompoc
# ozinki
# 390 || ozinki
# matsubase
# 391 || matsubase
# bac lieu
# 392 || bac lieu
# cap malheureux
# 393 || cap malheureux
# scarborough
# 394 || scarborough
# tazovskiy
# 395 || tazovskiy
# penzance
# 396 || penzance
# clyde river
# 397 || clyde river
# bandarbeyla
# 398 || bandarbeyla
# saint-louis
# 399 || saint-louis
# nortelandia
# 400 || nortelandia
# ahuimanu
# 401 || ahuimanu
# darayya
# 402 || darayya
# flin flon
# 403 || flin flon
# havoysund
# 404 || havoysund
# shache
# 405 || shache
# kununurra
# 406 || kununurra
# sinkat
# city not found
# meadow lake
# 407 || meadow lake
# parkes
# 408 || parkes
# beringovskiy
# 409 || beringovskiy
# piraquara
# 410 || piraquara
# angamacutiro
# city not found
# camacha
# 411 || camacha
# mentougou
# 412 || mentougou
# hoa binh
# 413 || hoa binh
# takab
# 414 || takab
# policoro
# 415 || policoro
# sur
# 416 || sur
# tiznit
# 417 || tiznit
# diffa
# 418 || diffa
# northam
# 419 || northam
# muros
# 420 || muros
# nanakuli
# 421 || nanakuli
# yermakovskoye
# 422 || yermakovskoye
# rawannawi
# city not found
# kapuskasing
# 423 || kapuskasing
# surin
# 424 || surin
# khasan
# 425 || khasan
# vale da amoreira
# 426 || vale da amoreira
# roald
# 427 || roald
# kiama
# 428 || kiama
# mogadishu
# 429 || mogadishu
# petrozavodsk
# 430 || petrozavodsk
# waipawa
# 431 || waipawa
# la sarre
# 432 || la sarre
# saint anthony
# 433 || saint anthony
# jian
# 434 || jian
# torbay
# 435 || torbay
# east brainerd
# 436 || east brainerd
# kutum
# 437 || kutum
# tres arroyos
# 438 || tres arroyos
# doha
# 439 || doha
# louisbourg
# city not found
# yamada
# 440 || yamada
# tekari
# 441 || tekari
# fairbanks
# 442 || fairbanks
# viligili
# city not found
# caraubas
# 443 || caraubas
# uwayl
# city not found
# lorengau
# 444 || lorengau
# malwan
# city not found
# zabaykalsk
# 445 || zabaykalsk
# kuche
# city not found
# gorontalo
# 446 || gorontalo
# fredericksburg
# 447 || fredericksburg
# bathsheba
# 448 || bathsheba
# markdale
# 449 || markdale
# lata
# 450 || lata
# port macquarie
# 451 || port macquarie
# birjand
# 452 || birjand
# shingu
# 453 || shingu
# buta
# 454 || buta
# recco
# 455 || recco
# sinnamary
# 456 || sinnamary
# fomboni
# 457 || fomboni

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Add lists to dictionary
weather_dict = {
     "City": city_count,
     "Lat": lats,
     "Lng": lngs,
     "Max Temp": temps,
     "Humidity": hums,
     "Cloudiness": clouds,
     "Wind Speed": winds,
     "Country": countries,
     "Date": dates
}

# Create DataFrame
city_weather = pd.DataFrame(data = weather_dict)
city_weather.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      bengkulu  -3.80  102.27     75.33        89          55        3.40
# 1  constitucion -35.33  -72.42     59.31        75           5        6.40
# 2          jalu  29.03   21.55     83.10        20           9       10.22
# 3        dikson  73.51   80.55     25.30        95         100       11.45
# 4      victoria  22.29  114.16     77.00        73          40       10.78
#
#   Country        Date
# 0      ID  1602878570
# 1      CL  1602878571
# 2      LY  1602878572
# 3      RU  1602878540
# 4      HK  1602878351

# %%
# Save city_weather to csv file
city_weather.to_csv("city_weather.csv")

#verify path
# !pwd
# Out:
# /c/classrepo/HomeWork_out/PythonAPI_HW/python-api-challenge/WeatherPy

# %%
# Not required - stats
city_weather.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  457.000000  457.000000  457.000000  457.000000  457.000000  457.000000
# mean    20.822670   17.092757   60.828906   71.054705   51.122538    8.493698
# std     34.511041   92.378476   20.333981   22.545064   40.190968    5.639897
# min    -54.800000 -175.200000   -1.800000    8.000000    0.000000    0.110000
# 25%     -5.520000  -60.280000   46.000000   59.000000    2.000000    4.450000
# 50%     25.880000   20.580000   64.220000   77.000000   54.000000    7.340000
# 75%     50.680000  101.450000   77.360000   88.000000   90.000000   11.410000
# max     78.220000  179.320000   96.870000  100.000000  100.000000   33.110000
#
#                Date
# count  4.570000e+02
# mean   1.602879e+09
# std    1.833125e+02
# min    1.602878e+09
# 25%    1.602879e+09
# 50%    1.602879e+09
# 75%    1.602879e+09
# max    1.602879e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Get the indices of cities that have humidity over 100%.
max_humidity = city_weather[city_weather["Humidity"] > 100].index

# Drop cities with humidity > 100 creating a new DataFrame
clean_city_weather = city_weather.drop(max_humidity, inplace=False)
clean_city_weather
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        bengkulu  -3.80  102.27     75.33        89          55        3.40
# 1    constitucion -35.33  -72.42     59.31        75           5        6.40
# 2            jalu  29.03   21.55     83.10        20           9       10.22
# 3          dikson  73.51   80.55     25.30        95         100       11.45
# 4        victoria  22.29  114.16     77.00        73          40       10.78
# ..            ...    ...     ...       ...       ...         ...         ...
# 452        shingu  33.73  135.98     57.94        91         100        7.83
# 453          buta   2.79   24.73     68.63        96          25        0.65
# 454         recco  44.36    9.14     55.99        86          19        4.90
# 455     sinnamary   5.38  -52.95     83.98        66           0       13.73
# 456       fomboni -12.28   43.74     79.38        71           1        3.85
#
#     Country        Date
# 0        ID  1602878570
# 1        CL  1602878571
# 2        LY  1602878572
# 3        RU  1602878540
# 4        HK  1602878351
# ..      ...         ...
# 452      JP  1602879110
# 453      CD  1602879111
# 454      IT  1602879112
# 455      GF  1602879113
# 456      KM  1602879115
#
# [457 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Scatter plot of latitude vs max tempurature
def latitude_plots(compare):
    plt.scatter(clean_city_weather["Lat"], clean_city_weather[compare], marker="o")
    
    # Graph properties
    plt.title(f"City Latitude vs {compare} (10/13/2020)")
    plt.ylabel(compare)
    plt.xlabel("Latitude")
    plt.grid(True)

    # Save figure
    plt.savefig(f"Lat_vs_{compare}.png")

    # Display
    plt.show()

# %%
compare_list = ["Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
for compare in compare_list:
    latitude_plots(compare)

# %% [markdown]
# Purpose: These plots show the latitude of cities and their corresponding weather condition.
# Observations:
# There is a correlation with regards to latitude and max tempurature. Correspondance results in a bell shaped curve.
# There may be some correlation between latitude and humidity, but it is difficult to make that determination based on this plot.
# There is no significant correspondence between latitude and either cloudiness or wind speed.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Separate out northern hemisphere
northern_df = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]

# Define X and Y values
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# y = -0.93x +94.05
# The r-value is: 0.7418802111146641

# %%
Observation: The r value, of 0.74, shows a strong correlation between latitude and max tempurature in the northern hemisphere.
This plot illustrates the closer to the equator the higher the maximum tempurate.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Separate out southern hemisphere
southern_df = clean_city_weather.loc[clean_city_weather["Lat"] <= 0]

# Define X and Y values
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# y = 0.62x +84.03
# The r-value is: 0.5313614304988733

# %%
Observation: The r value, of 0.53, shows a moderate correlation between latitude and max tempurature in the southern hemisphere.
This plot illustrates a trend towards higher maximum tempurates closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Separate out northern hemisphere
northern_df = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]

# Define X and Y values
x_values = northern_df['Lat']
y_values = northern_df['Humidity']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# y = 0.32x +57.63
# The r-value is: 0.07699622997835356

# %%
Observation: The r value, of 0.076, indicates a very weak correlation between latitude and humidity in the northern hemisphere.
Although there there is too much variation within the data to support correlation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Separate out southern hemisphere
southern_df = clean_city_weather.loc[clean_city_weather["Lat"] <= 0]

# Define X and Y values
x_values = southern_df['Lat']
y_values = southern_df['Humidity']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# y = 0.08x +74.46
# The r-value is: 0.003793935631235249

# %%
Observation: This plot and r value denote very weak to no correlation, in the southern hemisphere, between latitude and humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Separate out northern hemisphere
northern_df = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]

# Define X and Y values
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# y = 0.58x +26.15
# The r-value is: 0.0867005052830797

# %%
Observation: The r value of 0.086 indicates a very weak correlation between latitude and cloudiness in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Separate out southern hemisphere
southern_df = clean_city_weather.loc[clean_city_weather["Lat"] <= 0]

# Define X and Y values
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudines (%)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# y = 0.32x +63.06
# The r-value is: 0.013275154666915923

# %%
Observation: The r value of 0.013 indicates weak to no correlation between latitude and cloudiness in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Separate out northern hemisphere
northern_df = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]

# Define X and Y values
x_values = northern_df['Lat']
y_values = northern_df['Wind Speed']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# y = 0.04x +6.89
# The r-value is: 0.01785511732178768

# %%
Observation: The r value of 0.018 indicates weak to no correlation between latitude and wind speed in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Separate out southern hemisphere
southern_df = clean_city_weather.loc[clean_city_weather["Lat"] <= 0]

# Define X and Y values
x_values = southern_df['Lat']
y_values = southern_df['Wind Speed']

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create and lable plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Display graph
plt.show()
# Out:
# y = -0.05x +7.82
# The r-value is: 0.011919325656524734

# %%
Observation: The r value of 0.012 indicates weak to no correlation between latitude and wind speed in the southern hemisphere.
